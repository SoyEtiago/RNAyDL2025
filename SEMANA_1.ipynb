# %% [markdown]
# # Introducción a Python

# %% [markdown]
# ![Screenshot from 2024-07-25 15-08-32.png](data:image/png;base64,...)

# %% [markdown]
# # VARIBALES Y DATOS

# %% [markdown]
# ## DATOS NUMERICOS

# %%
# @title ENTEROS
#Puedo asignar el valor a una variable por medio del =
nombre = 10
entero_1 = 418

entero_2 =10

suma = entero_1 + entero_2

print("La suma del entero 1 y entero 2 es: ", suma)

resta = entero_1 - entero_2

print("La resta del entero 1 y entero 2 es: ", resta)
# Out:
# La suma del entero 1 y entero 2 es:  428
# La resta del entero 1 y entero 2 es:  408

# %%
# @title FLOTANTES
flotante_1 = 418.0

flotante_2 = 10.0

suma = flotante_1 + flotante_2

print("La suma del flotante 1 y flotante 2 es: ", suma)

resta = flotante_1 - flotante_2

print("La resta del entero 1 y entero 2 es: ", resta)
# Out:
# La suma del flotante 1 y flotante 2 es:  428.0
# La resta del entero 1 y entero 2 es:  408.0

# %%
type(entero_1)
# Out:
# int

# %%
# @title VARIABLES COMPLEJAS
complejo_1 = 4+3j

complejo_2 = 5+4j

suma = complejo_1 + complejo_2

print("La suma del complejo 1 y complejo 2 es: ", suma)

resta = complejo_1  - complejo_2

print("La resta del complejo 1 y complejo 2 es: ", resta)
# Out:
# La suma del complejo 1 y complejo 2 es:  (9+7j)
# La resta del complejo 1 y complejo 2 es:  (-1-1j)

# %%
# @title VARIABLES BOOLEANAS
bol_1 = True

bol_2 = True

print("El resultado de la variable 1 Y la variable 2 es: ", bol_1 and bol_2)

print("El resultado de la variable 1 O la variable 2 es: ", bol_1 or bol_2)

print("El resultado negado de la variable 1 es: ", not bol_1)
# Out:
# El resultado de la variable 1 Y la variable 2 es:  True
# El resultado de la variable 1 O la variable 2 es:  True
# El resultado negado de la variable 1 es:  False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def xor(a,b):
  xor = (((not a) and (b))or((a)and (not b)))
  #print(xor)
  return xor

# %%
xor_result= xor(bol_1, bol_2)

print("la xor de bol 1 y bol 2 es: ", xor_result)

resultado2 = xor(False,True)
print("el resultado es: ",resultado2)
# Out:
# la xor de bol 1 y bol 2 es:  False
# el resultado es:  True

# %% [markdown]
# ![Screenshot from 2024-07-25 15-09-38.png](data:image/png;base64,...)

# %%
print("Las variables son iguales?: ", bol_1 == bol_2)
print("Las variables no son iguales?:", bol_1 != bol_2)
print("Las variables son diferentes?:", bol_1 is not bol_2)

# %%
# @title Operadores numéricos
#En python podemos realiar operaciónes matematicas como suma, resta multiplicación, división, modulo y exponecial
a = 10
b = 3

sum = a+b

res = a-b

mul = a*b

div = a/b

mod = a%b

exp = a**b

div_ = a//b

print("Suma de a + b: ",sum)

print("Resta de a - b: ",res)

print("Multiplicación de a * b: ",mul)

print("División de a / b: ",div)

print("Modulo de a % b: ",mod)

print("Exponente base a de b: ",exp)

print("División entera de a // b: ",a//b)

# %%
int(3.0*2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# @title reasignación de variables

a = 6
b = 8
c = a + b
print("Imprimimos el valor de c ",c)
a = 10
print("Imprimimos el valor de a",a)

# %% [markdown]
# # EJERCICIO PARA DATOS NUMERICOS

# %% [markdown]
# Realice el codigo que calcule el promedio de cinco notas de un estudiante, la nota 1 tiene un valor del 25%, la nota 2 del 20%, la nota 3 del 5%, la nota 4 del 20% y la nota 5 del 30%

# %%
#Recuerde que para ingresar texto puede hacerlo por medio de input
#Ademas para forzar que el valor ingresado sea entero o flotante debe de colocarlo dentro del paretesis
#ejemplo
nota_3 = input("Por favor ingrese el valor de la nota 3   ")
nota_3 = float(nota_3)
nota_4 = input("Por favor ingrese el valor de la nota 4   ")
nota_4 = int(nota_4)
print("El valor de la nota 3 es de ",nota_3)
print("La nota 3 es de tipo ",type(nota_3))
print("El valor de la nota 4 es de ",nota_4)
print("La nota 4 es de tipo ",type(nota_4))

# %% [markdown]
# # DATOS TIPO CADENAS

# %% [markdown]
# ## VARIABLES STRINGS
# Representan a las cadenas y tambien es una forma de trabajar con texto

# %%
string_1 = 'Esta es una variable tipo string'
string_2 = ' y este es el complemento de dicha variable'

print(string_1 + string_2)

# %% [markdown]
# En los cuadernos, tambien podemos imprimir texto sin necesidad del comando print, simplemente colocamos el texto que deseamos entre comillas

# %%
'Este texto incluye una "" '

# %%
"Esta 'palabra' se encuentra escrita entre comillas simples"

# %%
"Esta \"palabra\" se encuentra escrita entre comillas dobles"

# %% [markdown]
# Agregar una tabulación en el texto

# %%
print("Un texto\tuna tabulación")

# %% [markdown]
# Agregar un salto de linea a un texto

# %%
print("Un texto\nuna nueva linea")

# %% [markdown]
# Para trabajar con las cadenas sin que las interprete hay que indicar que la cadena es crudo (raw)

# %%
print(r"C:\nombre\directorio")

# %%
s = "Una cadena" " compuesta de dos cadenas"
print(s)

# %%
diez_espacio = " "*10
print(diez_espacio + "un texto a diez espacios")

# %%
#Podemos tambien iterar cada elemento de la cadena, esto solicitando la posición con []
posicion_deseada = "prueba"
print("Solicito la palabra que se encuentra en la posición 3 dentro de la variable 'posicion_deseada' :  ",posicion_deseada[3])
print("Solicito la palabra que se encuentra entre la posición 2 y 4 dentro de la variable 'posicion_deseada' :  ",posicion_deseada[2:5])

# %%
#Cuando tenemos un texto separados por coma por ejemplo hola,nuevo,mundo
#podemos separa cada palabra con el comando .split y almacenarlo en un arreglo

split_ejemplo =  "hola,nuevo,mundo"
hola,nuevo,mundo =  split_ejemplo.split(',')

# %%
# @title
print(hola)
print(nuevo)
print(mundo)

# %% [markdown]
# # EJERCICIO PARA DATOS TIPO CADENA

# %% [markdown]
# Escriba una historia donde por cada reglon cuente con 8 palabras, esta historia debera estar almacenada en una variable, ademas debera imprimir un renglo entero de este parrafo

# %%
#Recuerde usar los saltos de lineas \n y los [] para solicitar posiciones

# %% [markdown]
# # Estructuras de datos

# %% [markdown]
# ## LISTAS

# %%
#LISTAS

arreglo = ['string_0',1,"posición 3" ,9]

print("arrelgo inicial = ", arreglo)

arreglo[2] = "posición nueva"

print("arrelgo final = ",arreglo)

arreglo.append('nuevo valor')

print("Se le agrego un nuevo valor en la ultima posición = ",arreglo)

# %%
#Tambien podemos unir listas por medio del +
a=['hola','vamos','a']
print(a+['agregar','un','arreglo','mas','usando','+'])

# %% [markdown]
# ## TUPLAS

# %%
#Son similares a las listas con las caracteriticas de que no son modificables
tupla_1 = ('1','hola',2,3)

print(type(tupla_1))

# %%
tupla_1[1] = 5 #Nos genera un error por que no podemos modificarla

# %% [markdown]
# ## DICIONARIOS

# %%
#diccionarios

dicionario_1 = {
    "clave_1" : 1234 ,
    "clave_2" : 45,
    "clave_3" : "esta es la clave 3" }


print("mostrar la clave 3", dicionario_1["clave_2"])

# %% [markdown]
# # CICLOS

# %% [markdown]
# ## Ciclo for

# %%
for iterador in range(0,10+1):

  print(iterador)

# %% [markdown]
# ## Ciclo while

# %%
iterador = 0
while iterador <= 10:
  print(iterador)
  iterador = iterador + 1

# %% [markdown]
# # CONDICIONALES

# %%
edad = int(input(" Ingrese por favor la edad"))

if edad == 18:
  print("La edad que tienes es ", edad)

elif edad < 18 :
  print("eres menor de edad")

else:
  print("eres mayor de edad")

# %% [markdown]
# # FUNCIONES

# %%
def HelloWorldXY(x, y):
  if (x < 10):
    print("Hello World, x was < 10")
  elif (x < 20):
    print("Hello World, x was >= 10 but < 20")
  else:
    print("Hello World, x was >= 20")
  return x + y

for i in range(8, 25, 5):  # i=8, 13, 18, 23 (start, stop, step)
  print("--- Now running with i: {}".format(i))
  r = HelloWorldXY(i,i)
  print("Result from HelloWorld: {}".format(r))

# %% [markdown]
# # ADICCIONALES

# %% [markdown]
# Realizar ejercicios que se encuentran en el siguiente link https://aprendeconalf.es/docencia/python/ejercicios/cadenas/
#
# Ver video para complementar los concoimientos basicos https://www.youtube.com/watch?v=chPhlsHoEPo
